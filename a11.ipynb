# %%
assignment 6

# %% [markdown]
# <h1>assignment 6
# <h2>q1

# %% [markdown]
# ![Screenshot 2025-05-03 152050.png](<attachment:Screenshot 2025-05-03 152050.png>)

# %% [markdown]
# ![Screenshot 2025-05-03 152042.png](<attachment:Screenshot 2025-05-03 152042.png>)

# %% [markdown]
# <h2>q2

# %% [markdown]
# ![Screenshot 2025-05-03 150826.png](<attachment:Screenshot 2025-05-03 150826.png>)

# %% [markdown]
# ![Screenshot 2025-05-03 150757.png](<attachment:Screenshot 2025-05-03 150757.png>)
